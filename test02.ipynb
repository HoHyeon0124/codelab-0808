# %% [markdown]
# <a href="https://colab.research.google.com/github/HoHyeon0124/codelab-0808/blob/master/test02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = '홍길동'
age = 100

# %%
# 자동완성 : 시작하는 문자 몇 개 + tab
