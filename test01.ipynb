# %% [markdown]
# <a href="https://colab.research.google.com/github/HoHyeon0124/codelab-0808/blob/master/test01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('welcome!! jupyter')
# Out:
# welcome!! jupyter

# %%
# shift+enter: 해당 셀 실행해주고, 다음 셀도 생성해줌
# ctrl+enter: 해당 셀 실행만!

# %%
# 셀 삭제: 초록색 뒷부분을 클릭 후, dd(x)
# 셀 아래 추가: 초록색 뒷 부분을 클릭 후, b
# 셀 위 추가: 초록색 뒷부분을 클릭 후, a
# 셀 복사: c, 셀 붙여넣기: v

# %%
print('변수값 출력')
# Out:
# 변수값 출력

# %%
name = 'hong'
age = 100

# %%
name, age
# Out:
# ('hong', 100)

# %%
print(name)
# Out:
# hong
