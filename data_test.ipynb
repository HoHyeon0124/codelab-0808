# %% [markdown]
# <a href="https://colab.research.google.com/github/HoHyeon0124/codelab-0808/blob/master/data_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("환영해 구글...........")
# Out:
# 환영해 구글...........

# %%
# 쉬프트 + 엔터 : 현재 셀 실행하고 다음 셀을 생성함.

# %%
data = input("아 집에 가고 싶다")
# Out:
# 아 집에 가고 싶다

# %%
""
